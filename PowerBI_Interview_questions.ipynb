# %% [markdown]
# <a href="https://colab.research.google.com/github/shareefat/POWER-BI-Projects/blob/main/PowerBI_Interview_questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Interview Questions of PowerBI
#
# 1. What is Power BI
#
# 2. What are main components in Power BI
#
# Power Query, Power View, Power bi desktop, Power bi service, Power BI Mobile
#
# 3. Power BI datasets?
#
# 4. Diff. types of visualizations available in Power BI
#
# 5. Power BI dashboard?
#
# 6. D/b/w Power BI Desktop and power bi service
#
# Power BI Desktop- used for designing, creating and publishing reports
#
# power bi service- A cloud based platform for sharing and collaborating on reports and dashboards
#
# 7. D/b/w  a report and dashboard in Power BI
#
# report- Multi-page , detailed insights with charts,tables...
#
# dashboard- A single page summary of key metrics
#
# 8. DAX?
# It is a formula language used in Power BI for creating calculated columns, measures and custom tables
#
# 9. D/b/w calculated columns and measures in Power BI
#
# measures- calculates a result based on user interaction with visuals (aggregated)
#
#
#  10. Power Query?
#
#  It is a data transformation and preparation engine used to connect , clean and reshape the data before loading it to the Power BI model.
#
# 11. Slicers in Power BI?
#
# visual filters that allows users to interactively filter data in reports and dashboards
#
# 12. Calculated table?
#
# created using DAX and is based on other table in the model
#
# 13. Explain the use of KPI
#
# KPI visuals display progress toward a measurable goal
#
# 14. Advantages of Power BI?
#
# Easy integration with multiple data sources
#
# interactive and shareable dashboards
#
# advanced analytics using DAX
#
# Cloud based accesibility
#
#
# 15. D/b/w Power BI and tableau
#
# Power BI integrates well with Microsoft products and is cost effective.
#
# Tableau offers more advanced visualization capabilities
#
# 16. How does Power BI handle missing or null values?
#
# 17. Some examples of data transformation in power query?
#
# 18. what is grouping in Power BI?
#
# Grouping combines similar data points into categories for better analysis
#
# 19. What is a heat map in Power BI?
#
# uses color codinng to represent data intensity or density
#
# 20. Explain DAX time intelligence funnction
#
# calculate data across time periods
#
# 21. types of DAX functions?
#
# 22. use of SUM() function in DAX
#
# 23. D/b/w SUM() and SUMX() function
#
# SUMX()- perorms row wise calculations before summing up the results
#
# 24. purpose of the RELATED() function?
#
# retrieves a value from a related table
#
# 25. purpose of the ALL() function?
#
# 26. BLANK() function
#
# 27. SWITCH() Function
#
#
# evaluates an expression against multiple values and return results accordingly.
#
# 28. CALENDER() function
#
# 29. FORMAT() function
#
# 30. CONCATENATE() Function
